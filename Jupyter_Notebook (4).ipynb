# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # My Jupiter Notebook on IBM Watson Studio

# %% [markdown]
# **Nazia Sulaiman**
#
# Data Scientist

# %% [markdown]
# *"I am interested in Data Science because I enjoy problem solving and statistical analysis. I would love to work for a  data driven innovative company."*

# %% [markdown]
# ### My code will do a simple multipication ie. 3 multiplied by 5

# %%
3*5
# Out:
# 15

# %% [markdown]
# ![photo-1583083527882-4bee9aba2eea.jpg](attachment:94e9748f-8771-4404-9383-ce16f6bcb658.jpg)
#
# * cat picture
#
# > "If the plan doesnt work change the plan but never the goal."
#
#  course detail link to [Data Scientist](http://coursera.org)
